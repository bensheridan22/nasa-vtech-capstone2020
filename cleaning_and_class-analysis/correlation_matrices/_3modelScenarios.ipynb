# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

models_3 = pd.read_csv("/Users/bensheridan/Downloads/threeModelScenario.csv")

# %%
#"number of models", "sample_index", 
mc_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
          "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
          "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
          "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
          "cov_55", "mlmc ams", 'mfmc ams']
acv_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
           "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
           "cov_04","cov_05","cov_11","cov_12","cov_13","cov_14","cov_15","cov_22",
           "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
           "cov_55", 'acvis ams', 'acvmf ams','acvkl ams','wrdiff ams']

pacv_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
            "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
            "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
            "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", 
            "cov_45", "cov_55", 'grdsr ams','grdmr ams','gissr ams','gismr ams','acvmfu ams',
            'gmfsr ams','gmfmr ams']

#"number of models", "sample_index", 
rec_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
          "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
          "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
          "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
          "cov_55", "mlmc ams", 'wrdiff ams', 'grdsr ams','grdmr ams']
ind_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
           "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
           "cov_04","cov_05","cov_11","cov_12","cov_13","cov_14","cov_15","cov_22",
           "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
           "cov_55", 'acvis ams', 'gissr ams','gismr ams']

multi_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
            "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
            "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
            "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", 
            "cov_45", "cov_55", 'mfmc ams','acvmf ams','acvkl ams','acvmfu ams', 'gmfsr ams','gmfmr ams']

# %% [markdown]
# # All algorithms

# %%
all_data = models_3[["mlmc ams", 'mfmc ams', 'wrdiff ams', 'grdsr ams','grdmr ams', 'acvis ams', 'gissr ams','gismr ams', 'acvmf ams','acvkl ams','acvmfu ams', 'gmfsr ams','gmfmr ams']]
all_alg_data = all_data.dropna()
all_alg_corr_matrix = np.corrcoef(all_alg_data.T, bias=True)
cols = all_alg_data.columns

cov_mat = all_alg_corr_matrix
plt.figure(figsize=(15,15))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',
                 fmt='.3f',
                 yticklabels=cols,
                 xticklabels=cols)
plt.title('Correlation Matrix of All AMS Algorithms - 3 Model Scenario', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod3/mod3AMSall.jpg")
# Out:
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: bias and ddof have no effect and are deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # By Class

# %%
monte_carlo_alg3 = models_3[mc_alg]
approx_control_var_alg3 = models_3[acv_alg]
parametric_acv_alg3 = models_3[pacv_alg]

data1 = monte_carlo_alg3.iloc[:, 27:30].dropna()
data2 = approx_control_var_alg3.iloc[:, 27:32].dropna()
data3 = parametric_acv_alg3.iloc[:, 27:35].dropna()

covMatrix1 = np.corrcoef(data1.T, bias=True)
cols1 = data1.columns

covMatrix2 = np.corrcoef(data2.T, bias=True)
cols2 = data2.columns

covMatrix3 = np.corrcoef(data3.T, bias=True)
cols3 = data3.columns
# Out:
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: bias and ddof have no effect and are deprecated
#   if __name__ == '__main__':
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning: bias and ddof have no effect and are deprecated
#   if sys.path[0] == '':
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: bias and ddof have no effect and are deprecated
#   from ipykernel import kernelapp as app

# %%
cov_mat = covMatrix1
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',    
                 fmt='.5f',
                 yticklabels=cols1,
                 xticklabels=cols1)
plt.title('Correlation Matrix of Analytic AMS Algorithms - 3 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod3/mod3AMSanalytical.jpg")

# %%
cov_mat = covMatrix2
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',  
                 fmt='.5f',
                 yticklabels=cols2,
                 xticklabels=cols2)
plt.title('Correlation Matrix of ACV AMS Algorithms - 3 Mod Scenario', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod3/mod3AMSacv.jpg")

# %%
cov_mat = covMatrix3
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',  
                 fmt='.5f',
                 yticklabels=cols3,
                 xticklabels=cols3)
plt.title('Correlation Matrix of P-ACV AMS Algorithms - 3 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod3/mod3AMSpacv.jpg")

# %% [markdown]
# # By Sampling Strategy

# %%
recur_diff_alg3 = models_3[rec_alg]
ind_samp_alg3 = models_3[ind_alg]
multifidel_alg3 = models_3[multi_alg]

#data = recur_diff_alg3.iloc[:, 31:59].dropna().sample(10000)

data1 = recur_diff_alg3.iloc[:, 27:31].dropna()
data2 = ind_samp_alg3.iloc[:, 27:31].dropna()
data3 = multifidel_alg3.iloc[:, 27:33].dropna()

covMatrix1 = np.corrcoef(data1.T, bias=True)
cols1 = data1.columns

covMatrix2 = np.corrcoef(data2.T, bias=True)
cols2 = data2.columns

covMatrix3 = np.corrcoef(data3.T, bias=True)
cols3 = data3.columns
# Out:
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: bias and ddof have no effect and are deprecated
#   # This is added back by InteractiveShellApp.init_path()
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: bias and ddof have no effect and are deprecated
#
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: bias and ddof have no effect and are deprecated

# %%
cov_mat = covMatrix1
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',   
                 fmt='.5f',
                 yticklabels=cols1,
                 xticklabels=cols1)
plt.title('Correlation Matrix of Rec Diff AMS Algorithms - 3 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod3/mod3AMSrecdiff.jpg")

# %%
cov_mat = covMatrix2
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',
                 fmt='.5f',
                 yticklabels=cols2,
                 xticklabels=cols2)
plt.title('Correlation Matrix of Ind Samp AMS Algorithms - 3 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod3/mod3AMSindsamp.jpg")

# %%
cov_mat = covMatrix3
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.5f',
                 cmap='coolwarm',                 
                 yticklabels=cols3,
                 xticklabels=cols3)
plt.title('Correlation Matrix of Multifidel AMS Algorithms - 3 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod3/mod3AMSmultif.jpg")
