# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

models_6 = pd.read_csv("/Users/bensheridan/Downloads/sixModelScenario.csv")

# %%
#"number of models", "sample_index", 
mc_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
          "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
          "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
          "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
          "cov_55", "mlmc", 'mfmc']
acv_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
           "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
           "cov_04","cov_05","cov_11","cov_12","cov_13","cov_14","cov_15","cov_22",
           "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
           "cov_55", 'acvis', 'acvmf','acvkl','wrdiff']

pacv_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
            "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
            "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
            "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", 
            "cov_45", "cov_55", 'grdsr','grdmr','gissr','gismr','acvmfu',
            'gmfsr','gmfmr']

#"number of models", "sample_index", 
rec_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
          "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
          "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
          "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
          "cov_55", "mlmc", 'wrdiff', 'grdsr','grdmr']
ind_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
           "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
           "cov_04","cov_05","cov_11","cov_12","cov_13","cov_14","cov_15","cov_22",
           "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", "cov_45", 
           "cov_55", 'acvis', 'gissr','gismr']

multi_alg = ["model_cost_0", "model_cost_1", "model_cost_2", "model_cost_3", 
            "model_cost_4", "model_cost_5", "cov_00", "cov_01", "cov_02", "cov_03",
            "cov_04","cov_05","cov_11","cov_12","cov_13", "cov_14","cov_15","cov_22",
            "cov_23","cov_24","cov_25","cov_33","cov_34", "cov_35", "cov_44", 
            "cov_45", "cov_55", 'acvmf','acvkl','acvmfu', 'gmfsr','gmfmr']

# %% [markdown]
# # All algorithms

# %%
all_data = models_6[["mlmc", 'mfmc', 'wrdiff', 'grdsr','grdmr', 'acvis', 'gissr','gismr', 'acvmf','acvkl','acvmfu', 'gmfsr','gmfmr']]

all_alg_data = all_data.dropna()
all_alg_corr_matrix = np.corrcoef(all_alg_data.T, bias=True)
cols = all_alg_data.columns

cov_mat = all_alg_corr_matrix
plt.figure(figsize=(15,15))
sns.set(font_scale=1.75)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',
                 fmt='.2f',
                 yticklabels=cols,
                 xticklabels=cols)
hm.set_yticklabels(cols, size = 25)
hm.set_xticklabels(cols, size = 25, rotation=90)
plt.title('Correlation Matrix of All Algorithms - 6 Model Scenario', size = 30)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod6/mod6AMSall.jpg")
# Out:
# /Users/bensheridan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: bias and ddof have no effect and are deprecated
#   after removing the cwd from sys.path.

# %% [markdown]
# # By Class

# %%
monte_carlo_alg6 = models_6[mc_alg]
approx_control_var_alg6 = models_6[acv_alg]
parametric_acv_alg6 = models_6[pacv_alg]

data1 = monte_carlo_alg6.iloc[:, 27:30].dropna()
data2 = approx_control_var_alg6.iloc[:, 27:32].dropna()
data3 = parametric_acv_alg6.iloc[:, 27:35].dropna()

covMatrix1 = np.corrcoef(data1.T, bias=True)
cols1 = data1.columns

covMatrix2 = np.corrcoef(data2.T, bias=True)
cols2 = data2.columns

covMatrix3 = np.corrcoef(data3.T, bias=True)
cols3 = data3.columns

# %%
cov_mat = covMatrix1
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',  
                 fmt='.5f',
                 yticklabels=cols1,
                 xticklabels=cols1)
plt.title('Correlation Matrix of Analytical AMS Algorithms - 6 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod6/mod6AMSanalytical.jpg")

# %%
cov_mat = covMatrix2
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.5f',
                 cmap='coolwarm',                 
                 yticklabels=cols2,
                 xticklabels=cols2)
plt.title('Correlation Matrix of ACV AMS Algorithms - 6 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod6/mod6AMSacv.jpg")

# %%
cov_mat = covMatrix3
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.4f',
                 cmap='coolwarm',                 
                 yticklabels=cols3,
                 xticklabels=cols3)
plt.title('Correlation Matrix of P-ACV AMS Algorithms - 6 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod6/mod6AMSpacv.jpg")

# %% [markdown]
# # By Sampling Strategy

# %%
recur_diff_alg6 = models_6[rec_alg]
ind_samp_alg6 = models_6[ind_alg]
multifidel_alg6 = models_6[multi_alg]

#data = recur_diff_alg6.iloc[:, 31:59].dropna().sample(10000)

data1 = recur_diff_alg6.iloc[:, 27:31].dropna()
data2 = ind_samp_alg6.iloc[:, 27:31].dropna()
data3 = multifidel_alg6.iloc[:, 27:33].dropna()

covMatrix1 = np.corrcoef(data1.T, bias=True)
cols1 = data1.columns

covMatrix2 = np.corrcoef(data2.T, bias=True)
cols2 = data2.columns

covMatrix3 = np.corrcoef(data3.T, bias=True)
cols3 = data3.columns

# %%
cov_mat = covMatrix1
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',   
                 fmt='.5f',
                 yticklabels=cols1,
                 xticklabels=cols1)
plt.title('Correlation Matrix of Rec Diff AMS Algorithms - 6 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod6/mod6AMSrecdiff.jpg")

# %%
cov_mat = covMatrix2
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm', 
                 fmt='.5f',
                 yticklabels=cols2,
                 xticklabels=cols2)
plt.title('Correlation Matrix of Ind Samp AMS Algorithms - 6 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod6/mod6AMSindsamp.jpg")

# %%
cov_mat = covMatrix3
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat,
                 cbar=True,
                 annot=True,
                 square=True,
                 cmap='coolwarm',    
                 fmt='.5f',
                 yticklabels=cols3,
                 xticklabels=cols3)
plt.title('Correlation Matrix of Multifidel AMS Algorithms - 6 Mod Scen', size = 20)
plt.tight_layout()
plt.savefig("/Users/bensheridan/Documents/Senior/CMDACapstone/figures/mod6/mod6AMSmultif.jpg")

# %% [markdown]
# ### * MFMC has 186 non-NaN values in the 6-model scenarios, so it was excluded from this matrix

# %%
plt.savefig("/")

# %%
pd.set_option('display.max_columns', None)
models_6corr.head()

# %% [markdown]
# # machine learning hopefully

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
models_6cost = pd.read_csv("/Users/bensheridan/Downloads/mod6cost.csv")

# %%
models_6corr = models_6cost[['model_cost_1', 'model_cost_2', 'model_cost_3',
                             'model_cost_4', 'model_cost_5', 'corr_01', 'corr_02', 
                             'corr_03', 'corr_04', 'corr_05', 'corr_12', 'corr_13', 
                             'corr_14', 'corr_15', 'corr_23', 'corr_24', 'corr_25', 
                             'corr_34', 'corr_35', 'corr_45']]

# %%
X = models_6.iloc[:, 1:28].values
#X = models_6corr.values
y = models_6.iloc[:, 30].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
# Importing the Keras libraries and packages
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from tensorflow.keras import backend

# %%
models_6corr.head()

# %% [markdown]
# # att 2

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, datetime

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import xgboost as xgb

import plotly.graph_objects as go

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler

# simple data cleaning
X = models_6corr
y = models_6.iloc[:, 29]

# impute the missing values and create the missing value indicator variables for each numeric column.
numeric_cols = X.columns.values

for col in numeric_cols:
    missing = X[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  # only do the imputation for the columns that have missing values.
        print('imputing missing values for: {}'.format(col))
        df['{}_ismissing'.format(col)] = missing
        med = X[col].median()
        X[col] = X[col].fillna(med)
 

# split the data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)


# Need to scale the features for neural networks, otherwise the training doesn't converge.
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
# This returns a multi-layer-perceptron model in Keras.
def get_keras_model(num_hidden_layers, 
                    num_neurons_per_layer, 
                    dropout_rate, 
                    activation):
    # create the MLP model.
    
    # define the layers.
    inputs = tf.keras.Input(shape=(X_train_scaled.shape[1],))  # input layer.
    x = layers.Dropout(dropout_rate)(inputs) # dropout on the weights.
    
    # Add the hidden layers.
    for i in range(num_hidden_layers):
        x = layers.Dense(num_neurons_per_layer, 
                         activation=activation)(x)
        x = layers.Dropout(dropout_rate)(x)
    
    # output layer.
    outputs = layers.Dense(1, activation='linear')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model
    

# This function takes in the hyperparameters and returns a score (Cross validation).
def keras_mlp_cv_score(parameterization, weight=None):
    
    model = get_keras_model(parameterization.get('num_hidden_layers'),
                            parameterization.get('neurons_per_layer'),
                            parameterization.get('dropout_rate'),
                            parameterization.get('activation'))
    
    opt = parameterization.get('optimizer')
    opt = opt.lower()
    
    learning_rate = parameterization.get('learning_rate')
    
    if opt == 'adam':
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif opt == 'rms':
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    else:
        optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
    
    NUM_EPOCHS = 50
    
    # Specify the training configuration.
    model.compile(optimizer=optimizer,
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=['mse'])

    data = X_train_scaled
    labels = y_train.values
    
    # fit the model using a 20% validation set.
    res = model.fit(data, labels, epochs=NUM_EPOCHS, batch_size=parameterization.get('batch_size'),
                    validation_split=0.2)
    
    # look at the last 10 epochs. Get the mean and standard deviation of the validation score.
    last10_scores = np.array(res.history['val_loss'][-10:])
    mean = last10_scores.mean()
    sem = last10_scores.std()
    
    # If the model didn't converge then set a high loss.
    if np.isnan(mean):
        return 9999.0, 0.0
    
    return mean, sem

# %%
# Define the search space.
parameters=[
    {
        "name": "learning_rate",
        "type": "range",
        "bounds": [0.0001, 0.5],
        "log_scale": True,
    },
    {
        "name": "dropout_rate",
        "type": "range",
        "bounds": [0.01, 0.5],
        "log_scale": True,
    },
    {
        "name": "num_hidden_layers",
        "type": "range",
        "bounds": [1, 10],
        "value_type": "int"
    },
    {
        "name": "neurons_per_layer",
        "type": "range",
        "bounds": [1, 300],
        "value_type": "int"
    },
    {
        "name": "batch_size",
        "type": "choice",
        "values": [8, 16, 32, 64, 128, 256],
    },
    
    {
        "name": "activation",
        "type": "choice",
        "values": ['tanh', 'sigmoid', 'relu'],
    },
    {
        "name": "optimizer",
        "type": "choice",
        "values": ['adam', 'rms', 'sgd'],
    },
]

# %%
# import more packages
from ax.service.ax_client import AxClient
from ax.utils.notebook.plotting import render, init_notebook_plotting

init_notebook_plotting()

ax_client = AxClient()

# create the experiment.
ax_client.create_experiment(
    name="keras_experiment",
    parameters=parameters,
    objective_name='keras_cv',
    minimize=True)

def evaluate(parameters):
    return {"keras_cv": keras_mlp_cv_score(parameters)}

# Based on the search space, this will use Sobol (https://en.wikipedia.org/wiki/Sobol_sequence) instead of a Guassian Process (GPEI).
#
# From the source code:
#     """We should use only Sobol and not GPEI if:
#     1. there are less continuous parameters in the search space than the sum of
#     options for the choice parameters,
#     2. the number of total iterations in the optimization is known in advance and
#     there are less distinct points in the search space than the known intended
#     number of total iterations.
#     """

# Sobol sequences seem to be better than random for high-dimensional spaces:
# https://en.wikipedia.org/wiki/Quasi-Monte_Carlo_method

# %%
for i in range(25):
    parameters, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(trial_index=trial_index, raw_data=evaluate(parameters))

# %%
ax_client.get_trials_data_frame().sort_values('trial_index')

# %%
best_parameters, values = ax_client.get_best_parameters()

# the best set of parameters.
for k in best_parameters.items():
    print(k)

print()

# the best score achieved.
means, covariances = values
print(means)

# %%
render(ax_client.get_optimization_trace())

# %%
# train the model on the full training set and test.
keras_model = get_keras_model(best_parameters['num_hidden_layers'], 
                              best_parameters['neurons_per_layer'], 
                              best_parameters['dropout_rate'],
                              best_parameters['activation'])

opt = best_parameters['optimizer']
opt = opt.lower()

learning_rate = best_parameters['learning_rate']

if opt == 'adam':
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
elif opt == 'rms':
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
else:
    optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)

NUM_EPOCHS = 200

# Specify the training configuration.
keras_model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['mse'])

data = X_train_scaled
labels = y_train.values
res = keras_model.fit(data, labels, epochs=NUM_EPOCHS, batch_size=best_parameters['batch_size'])

# %%
test_pred = keras_model.predict(X_test_scaled)
print(mean_squared_error(y_test.values, test_pred))

# %%
#import sklearn.metrics
sklearn.metrics.r2_score(y_test.values, test_pred)

# %%
print(1-(1-sklearn.metrics.r2_score(y_test.values, test_pred))*((len(X_test_scaled)-1)/(len(X_test_scaled)-len(X_test_scaled[0])-1)))

# %%
# %store best_parameters

# %%
#%store -r best_parameters to get best_parameters back!

# %% [markdown]
# # Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
x = models_6corr
y = models_6[['acvis']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
x = models_6corr
y = models_6[['acvis']]

polynomial_features = PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print(rmse)
print(r2)
# Out:
# 0.0017298670224577166
# 0.8664392386496191

# %%
resid = y.acvis - y_poly_pred

resid

# %%
resid.shape

# %%
y_poly_pred

# %%
import seaborn as sns

plt.plot(resid, y_poly_pred[0])
plt.xlabel("Fitted values")
plt.title('Residual plot')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-6d583469fea0> in <module>()
#       1 import seaborn as sns
#       2
# ----> 3 plt.plot(resid, y_poly_pred[0])
#       4 plt.xlabel("Fitted values")
#       5 plt.title('Residual plot')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
# ...

# %%
models_6.head()
# Out:
#    Unnamed: 0  model_cost_0  model_cost_1  model_cost_2  model_cost_3  \
# 0           0          0.01  6.893843e-03  4.797401e-04  3.595060e-06
# 1           1          0.01  4.868312e-08  1.852179e-05  4.701427e-07
# 2           2          0.01  1.096121e-06  2.773456e-07  5.696803e-04
# 3           3          0.01  7.396345e-07  1.234551e-06  5.291192e-07
# 4           4          0.01  1.051089e-06  1.586929e-07  1.459269e-04
#
#    model_cost_4  model_cost_5  cov_00    cov_01    cov_02  ...     grdmr  \
# 0  2.667900e-08  6.205291e-07     1.0 -0.279112 -0.467344  ...  0.002927
# 1  4.706323e-07  6.871278e-05     1.0 -0.100446 -0.259295  ...  0.002210
# 2  1.200490e-07  1.652048e-04     1.0  0.680340 -0.041882  ...  0.003982
# 3  2.216641e-05  6.973285e-06     1.0  0.462252 -0.063446  ...  0.000856
# 4  5.177773e-04  3.947533e-08     1.0 -0.592488  0.248616  ...  0.002343
#
#    grdmr ams     grdsr  grdsr ams  mfmc  mfmc ams      mlmc  mlmc ams  \
# ...
